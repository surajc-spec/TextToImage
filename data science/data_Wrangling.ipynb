# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel("wrangling.xlsx")
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     30 non-null     object
#  1   Age      30 non-null     float64
#  2   Grade    30 non-null     object
#  3   Class    30 non-null     float64
#  4   Subject  30 non-null     object
#  5   Marks    30 non-null     float64
#  6   Roll No  32 non-null     int64
#  7   Percent  30 non-null     float64
#  8   City     30 non-null     object
#  9   Bday     30 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 2.6+ KB

# %%
df.isnull().sum()
# Out:
# Name       2
# Age        2
# Grade      2
# Class      2
# Subject    2
# Marks      2
# Roll No    0
# Percent    2
# City       2
# Bday       2
# dtype: int64

# %%
df.Age.fillna(df['Age'].mean())
# Out:
# 0     14.0
# 1     15.0
# 2     13.0
# 3     14.0
# 4     15.0
# 5     14.0
# 6     13.0
# 7     15.0
# 8     13.0
# 9     14.0
# 10    14.0
# 11    15.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    14.0
# 16    13.0
# 17    15.0
# 18    14.0
# 19    13.0
# 20    15.0
# 21    14.0
# 22    13.0
# 23    14.0
# 24    15.0
# 25    13.0
# 26    14.0
# 27    15.0
# 28    13.0
# 29    14.0
# 30    14.0
# 31    14.0
# Name: Age, dtype: float64

# %%
df.isnull().sum()
# Out:
# Name       2
# Age        2
# Grade      2
# Class      2
# Subject    2
# Marks      2
# Roll No    0
# Percent    2
# City       2
# Bday       2
# dtype: int64

# %%
df.Age.unique()
# Out:
# array([14., 15., 13., nan])

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_25064\694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df.isnull().sum()
# Out:
# Name       2
# Age        0
# Grade      2
# Class      2
# Subject    2
# Marks      2
# Roll No    0
# Percent    2
# City       2
# Bday       2
# dtype: int64

# %%
df.Name.unique()
# Out:
# array(['Aarya Singh', 'Rohan Mehta', 'Tanvi Desai', 'Aryan Joshi',
#        'Neha Patil', 'Karan Shah', 'Sneha Rao', 'Varun Nair',
#        'Priya Kulkarni', 'Rahul Yadav', 'Meera Iyer', 'Siddharth G',
#        'Aisha Khan', 'Parth Deshmukh', 'Kavya Jain', 'Yash Pawar',
#        'Ananya Reddy', 'Tushar Jadhav', 'Ishita Modi', 'Arjun Bhat',
#        'Snehal Khedekar', 'Krish Gupta', 'Riya Salunke', 'Pranav Desai',
#        'Sanya Lokhande', 'Omkar Shinde', 'Disha More', 'Viraj Kadam',
#        'Shruti Gokhale', 'Atharv Naik', nan], dtype=object)

# %%
df['Marks'].fillna(df['Marks'].mean(),inplace=True)
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_25064\3876461913.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].mean(),inplace=True)

# %%
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df['Class'].fillna(df['Class'].mean(),inplace=True)
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_25064\4133028289.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Class'].fillna(df['Class'].mean(),inplace=True)

# %%
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df.isnull().sum()
# Out:
# Name       2
# Age        0
# Grade      2
# Class      0
# Subject    2
# Marks      0
# Roll No    0
# Percent    2
# City       2
# Bday       2
# dtype: int64

# %%
df['Subject'].fillna(df['Subject'].mode()[0],inplace=True)
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df['Name'].fillna(df['Name'].mode()[0],inplace=True)
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df['Grade'].fillna(df['Grade'].mode()[0],inplace=True)
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df['Percent'].fillna(df['Percent'].mean(),inplace=True)
df
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_25064\2283113690.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Percent'].fillna(df['Percent'].mean(),inplace=True)
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# ...

# %%
df['City'].fillna(df['City'].mode()[0],inplace=True)
df
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_25064\1421383191.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna(df['City'].mode()[0],inplace=True)
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# ...

# %%
df['Bday'].fillna(df['Bday'].mean(),inplace=True)
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %%
df.isnull().sum()
# Out:
# Name       0
# Age        0
# Grade      0
# Class      0
# Subject    0
# Marks      0
# Roll No    0
# Percent    0
# City       0
# Bday       0
# dtype: int64

# %% [markdown]
# # now remove duplicate values
# # false represents that the duplicates are present and true represents that duplicates are not present

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0  Science   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0  English   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0  Science   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0  English   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0  Science   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0  English   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0  Science   92.0      101     0.92
# ...

# %% [markdown]
# # now perform data normalization

# %%
df.Subject.unique()
# Out:
# array(['Science', 'Maths', 'English', 'History'], dtype=object)

# %%
df['Subject'].replace({'Science':'sci','English':'Eng'},inplace=True)
df
# Out:
#                Name   Age Grade  Class  Subject  Marks  Roll No  Percent  \
# 0       Aarya Singh  14.0     A    9.0      sci   92.0      101     0.92
# 1       Rohan Mehta  15.0     A   10.0    Maths   92.0      101     0.92
# 2       Tanvi Desai  13.0     A    8.0      Eng   92.0      101     0.92
# 3       Aryan Joshi  14.0     A    9.0  History   92.0      101     0.92
# 4        Neha Patil  15.0     A   10.0      sci   92.0      101     0.92
# 5        Karan Shah  14.0     A    9.0    Maths   92.0      101     0.92
# 6         Sneha Rao  13.0     A    8.0      Eng   92.0      101     0.92
# 7        Varun Nair  15.0     A   10.0  History   92.0      101     0.92
# 8    Priya Kulkarni  13.0     A    8.0      sci   92.0      101     0.92
# 9       Rahul Yadav  14.0     A    9.0    Maths   92.0      101     0.92
# 10       Meera Iyer  14.0     A    9.0      Eng   92.0      101     0.92
# 11      Siddharth G  15.0     A   10.0      sci   92.0      101     0.92
# ...
