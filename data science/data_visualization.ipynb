# %% [markdown]
# # data visulization

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#how to plot the number of survivrd passengers
df.survived.value_counts().plot()
# Out:
# <Axes: xlabel='survived'>

# %%
df.survived.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
df.survived.value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(x='survived',hue='sex',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# # how to finnd the fare rate w.r.t age

# %%
plt.scatter(x='fare',y='age',data=df)

# %%
sns.scatterplot(data=df,x='fare',y='age',hue='pclass')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.barplot(data=df,x='fare',y='age',hue='pclass')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.barplot(data=df,x='fare',y='sex',hue='pclass')
# Out:
# <Axes: xlabel='fare', ylabel='sex'>

# %%
sns.barplot(data=df,y='fare',x='sex',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %% [markdown]
# # how to get pairplot of same data

# %%
sns.pairplot(df)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
df.hist(bins=5,figsize=(5.5,6.5))
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
df.hist(bins=5, figsize =(5.5,6.5), grid= False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
#visualize the survival rate with age of passengers

# %%
survived_age=df.groupby('age')['survived'].mean()
survived_age
# Out:
# age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
#         ...
# 70.00    0.0
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 80.00    1.0
# Name: survived, Length: 88, dtype: float64

# %%
plt.plot(survived_age.index,survived_age.values)
plt.title('Survival Rate by age!')
plt.xlabel('age')
plt.ylabel('survived_age')

plt.show()
