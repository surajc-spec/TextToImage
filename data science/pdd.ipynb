# %%
import pandas as pd

# %%
pd.read_excel("pd.xlsx")
# Out:
#         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development

# %%
df=pd.read_excel("pd.xlsx")
df
# Out:
#         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development

# %%
df.head()
# Out:
#         Name   Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi      Pune   20           55          160    Computer Graphics
# 1         Om    Nashik   21           68          172    Operating Systems
# 2      Suraj    Nagpur   22           70          178    Computer Networks
# 3   Abhishek    Mumbai   23           75          180  Database Management
# 4   Shrishee  Kolhapur   20           52          158          Mathematics

# %%
df.tail()
# Out:
#        Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 1        Om      Nashik   21           68          172    Operating Systems
# 2     Suraj      Nagpur   22           70          178    Computer Networks
# 3  Abhishek      Mumbai   23           75          180  Database Management
# 4  Shrishee    Kolhapur   20           52          158          Mathematics
# 5    Shreya  Aurangabad   21           54          162      Web Development

# %%
df
# Out:
#         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development>

# %%
df.info
# Out:
# <bound method DataFrame.info of         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development>

# %%
df.sort_index(ascending=True)
# Out:
#         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development

# %%
df.sort_index(ascending=False)
# Out:
#         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 5     Shreya  Aurangabad   21           54          162      Web Development
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 1         Om      Nashik   21           68          172    Operating Systems
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics

# %%
df.shape
# Out:
# (6, 6)

# %%
df.T
# Out:
#                                   0                  1                  2  \
# Name                      Vaishnavi                 Om              Suraj
# Address                        Pune             Nashik             Nagpur
# Age                              20                 21                 22
# Weight (kg)                      55                 68                 70
# Height (cm)                     160                172                178
# Favorite Subject  Computer Graphics  Operating Systems  Computer Networks
#
#                                     3            4                5
# Name                         Abhishek     Shrishee           Shreya
# Address                        Mumbai     Kolhapur       Aurangabad
# Age                                23           20               21
# Weight (kg)                        75           52               54
# Height (cm)                       180          158              162
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.dtypes
# Out:
# Name                object
# Address             object
# Age                  int64
# Weight (kg)          int64
# Height (cm)          int64
# Favorite Subject    object
# dtype: object

# %%
df.sort_index()
# Out:
#         Name     Address  Age  Weight (kg)  Height (cm)     Favorite Subject
# 0  Vaishnavi        Pune   20           55          160    Computer Graphics
# 1         Om      Nashik   21           68          172    Operating Systems
# 2      Suraj      Nagpur   22           70          178    Computer Networks
# 3   Abhishek      Mumbai   23           75          180  Database Management
# 4   Shrishee    Kolhapur   20           52          158          Mathematics
# 5     Shreya  Aurangabad   21           54          162      Web Development

# %%
import pandas as pd
pd.__version__
print(pd.__version__)
# Out:
# 2.3.0

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 2cc37625532045f4ac55b27176454bbbc9baf213
# python                : 3.12.2
# python-bits           : 64
# OS                    : Windows
# OS-release            : 11
# Version               : 10.0.26100
# machine               : AMD64
# processor             : AMD64 Family 23 Model 160 Stepping 0, AuthenticAMD
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_India.1252
#
# pandas                : 2.3.0
# numpy                 : 2.1.3
# pytz                  : 2025.2
# dateutil              : 2.9.0.post0
# pip                   : 25.0.1
# Cython                : None
# sphinx                : None
# IPython               : 9.3.0
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : 4.13.3
# blosc                 : None
# bottleneck            : None
# dataframe-api-compat  : None
# ...

# %%
pd.DataFrame({'col A':[1,2,3,4,5],'col B':[6,7,8,9,12]})
# Out:
#    col A  col B
# 0      1      6
# 1      2      7
# 2      3      8
# 3      4      9
# 4      5     12

# %%
data_table=pd.DataFrame({'col A':[1,2,3,4,5],'col B':[6,7,8,9,12]})
print(data_table)
# Out:
#    col A  col B
# 0      1      6
# 1      2      7
# 2      3      8
# 3      4      9
# 4      5     12

# %%
data_table=pd.DataFrame({'col A':[1,2,3,4,5],'col B':[6,7,8,9,12]})
pd.DataFrame(data_table)
# Out:
#    col A  col B
# 0      1      6
# 1      2      7
# 2      3      8
# 3      4      9
# 4      5     12

# %%
data_table.describe
# Out:
# <bound method NDFrame.describe of    col A  col B
# 0      1      6
# 1      2      7
# 2      3      8
# 3      4      9
# 4      5     12>

# %%
data_table.shape
# Out:
# (5, 2)

# %%
#learning seaborn library
#syntax:
#    sns.load_dataset("titanic")

# %% [markdown]
# import seaborn as sns
# import pandas as pd
# import Numpy as np

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(300)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0           0       3    male  22.0      1      0    7.2500        S  Third
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 2           1       3  female  26.0      0      0    7.9250        S  Third
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 4           0       3    male  35.0      0      0    8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 295         0       1    male   NaN      0      0   27.7208        C  First
# 296         0       3    male  23.5      0      0    7.2292        C  Third
# 297         0       1  female   2.0      1      2  151.5500        S  First
# 298         1       1    male   NaN      0      0   30.5000        S  First
# 299         1       1  female  50.0      0      1  247.5208        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(df.head(300))
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0           0       3    male  22.0      1      0    7.2500        S  Third
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 2           1       3  female  26.0      0      0    7.9250        S  Third
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 4           0       3    male  35.0      0      0    8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 295         0       1    male   NaN      0      0   27.7208        C  First
# 296         0       3    male  23.5      0      0    7.2292        C  Third
# 297         0       1  female   2.0      1      2  151.5500        S  First
# 298         1       1    male   NaN      0      0   30.5000        S  First
# 299         1       1  female  50.0      0      1  247.5208        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pd.set_option('display.max_rows', 1000)
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 2           1       3  female  26.00      0      0    7.9250        S   Third
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 4           0       3    male  35.00      0      0    8.0500        S   Third
# 5           0       3    male    NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# ...

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.adult_male
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27      True
# 28     False
# 29      True
# 30      True
# 31     False
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38     False
# 39     False
# 40     False
# 41     False
# 42      True
# 43     False
# 44     False
# 45      True
# 46      True
# 47     False
# 48      True
# 49     False
# 50     False
# 51      True
# 52     False
# 53     False
# 54      True
# 55      True
# 56     False
# 57      True
# 58     False
# 59     False
# 60      True
# 61     False
# 62      True
# 63     False
# 64      True
# 65      True
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.T
# Out:
#                      0          1            2            3            4    \
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# ...

# %% [markdown]
# # Reverse order

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 2           1       3  female  26.00      0      0    7.9250        S   Third
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 4           0       3    male  35.00      0      0    8.0500        S   Third
# 5           0       3    male    NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# ...

# %%
#reverse row order
df.loc[::-1].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
#first are row denoted by single colon and second is no of cols
df.loc[:,::-1].head()
# Out:
#    alone alive  embark_town deck  adult_male    who  class embarked     fare  \
# 0  False    no  Southampton  NaN        True    man  Third        S   7.2500
# 1  False   yes    Cherbourg    C       False  woman  First        C  71.2833
# 2   True   yes  Southampton  NaN       False  woman  Third        S   7.9250
# 3  False   yes  Southampton    C       False  woman  First        S  53.1000
# 4   True    no  Southampton  NaN        True    man  Third        S   8.0500
#
#    parch  sibsp   age     sex  pclass  survived
# 0      0      1  22.0    male       3         0
# 1      0      1  38.0  female       1         1
# 2      0      0  26.0  female       3         1
# 3      0      1  35.0  female       1         1
# 4      0      0  35.0    male       3         0

# %%
df.loc[:,::-1].reset_index(drop=True)
# Out:
#      alone alive  embark_town deck  adult_male    who   class embarked  \
# 0    False    no  Southampton  NaN        True    man   Third        S
# 1    False   yes    Cherbourg    C       False  woman   First        C
# 2     True   yes  Southampton  NaN       False  woman   Third        S
# 3    False   yes  Southampton    C       False  woman   First        S
# 4     True    no  Southampton  NaN        True    man   Third        S
# 5     True    no   Queenstown  NaN        True    man   Third        Q
# 6     True    no  Southampton    E        True    man   First        S
# 7    False    no  Southampton  NaN       False  child   Third        S
# 8    False   yes  Southampton  NaN       False  woman   Third        S
# 9    False   yes    Cherbourg  NaN       False  child  Second        C
# 10   False   yes  Southampton    G       False  child   Third        S
# 11    True   yes  Southampton    C       False  woman   First        S
# ...

# %%
df.select_dtypes(include=["number"])
# Out:
#      survived  pclass    age  sibsp  parch      fare
# 0           0       3  22.00      1      0    7.2500
# 1           1       1  38.00      1      0   71.2833
# 2           1       3  26.00      0      0    7.9250
# 3           1       1  35.00      1      0   53.1000
# 4           0       3  35.00      0      0    8.0500
# 5           0       3    NaN      0      0    8.4583
# 6           0       1  54.00      0      0   51.8625
# 7           0       3   2.00      3      1   21.0750
# 8           1       3  27.00      0      2   11.1333
# 9           1       2  14.00      1      0   30.0708
# 10          1       3   4.00      1      1   16.7000
# 11          1       1  58.00      0      0   26.5500
# 12          0       3  20.00      0      0    8.0500
# 13          0       3  39.00      1      5   31.2750
# 14          0       3  14.00      0      0    7.8542
# 15          1       2  55.00      0      0   16.0000
# 16          0       3   2.00      4      1   29.1250
# ...

# %%
df.select_dtypes(include=["number"]).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500
