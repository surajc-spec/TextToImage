# %% [markdown]
# # REVERSE DATAFRAME ROW AND COLUMNS
# # date: 24/6

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df.load_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.load_data
#
# NameError: name 'df' is not defined

# %%
df.load_data("titanic")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.load_data("titanic")
#
# NameError: name 'df' is not defined

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[:: -1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 0           0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[:: -1].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
df.loc[:, ::-1]
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[:,:: -1].head()
# Out:
#    alone alive  embark_town deck  adult_male    who  class embarked     fare  \
# 0  False    no  Southampton  NaN        True    man  Third        S   7.2500
# 1  False   yes    Cherbourg    C       False  woman  First        C  71.2833
# 2   True   yes  Southampton  NaN       False  woman  Third        S   7.9250
# 3  False   yes  Southampton    C       False  woman  First        S  53.1000
# 4   True    no  Southampton  NaN        True    man  Third        S   8.0500
#
#    parch  sibsp   age     sex  pclass  survived
# 0      0      1  22.0    male       3         0
# 1      0      1  38.0  female       1         1
# 2      0      0  26.0  female       3         1
# 3      0      1  35.0  female       1         1
# 4      0      0  35.0    male       3         0

# %%
df.loc[:, : : -1]
# Out:
#      alone alive  embark_town deck  adult_male    who   class embarked  \
# 0    False    no  Southampton  NaN        True    man   Third        S
# 1    False   yes    Cherbourg    C       False  woman   First        C
# 2     True   yes  Southampton  NaN       False  woman   Third        S
# 3    False   yes  Southampton    C       False  woman   First        S
# 4     True    no  Southampton  NaN        True    man   Third        S
# ..     ...   ...          ...  ...         ...    ...     ...      ...
# 886   True    no  Southampton  NaN        True    man  Second        S
# 887   True   yes  Southampton    B       False  woman   First        S
# 888  False    no  Southampton  NaN       False  woman   Third        S
# 889   True   yes    Cherbourg    C        True    man   First        C
# 890   True    no   Queenstown  NaN        True    man   Third        Q
#
#         fare  parch  sibsp   age     sex  pclass  survived
# ...

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.select_dtypes(include=['number']).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
df.select_dtypes(exclude=["number"]).head()
# Out:
#       sex embarked  class    who  adult_male deck  embark_town alive  alone
# 0    male        S  Third    man        True  NaN  Southampton    no  False
# 1  female        C  First  woman       False    C    Cherbourg   yes  False
# 2  female        S  Third  woman       False  NaN  Southampton   yes   True
# 3  female        S  First  woman       False    C  Southampton   yes  False
# 4    male        S  Third    man        True  NaN  Southampton    no   True

# %%
df.select_dtypes(include=['object'])
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 3    female        S  woman  Southampton   yes
# 4      male        S    man  Southampton    no
# ..      ...      ...    ...          ...   ...
# 886    male        S    man  Southampton    no
# 887  female        S  woman  Southampton   yes
# 888  female        S  woman  Southampton    no
# 889    male        C    man    Cherbourg   yes
# 890    male        Q    man   Queenstown    no
#
# [891 rows x 5 columns]

# %%
df.select_dtypes(include=['bool''number'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.select_dtypes(include=['bool''number'])
#
# File c:\Users\SURAJ CHOUGULE\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5067, in DataFrame.select_dtypes(self, include, exclude)
#    5064             converted_dtypes.append(infer_dtype_from_object(dtype))
#    5065     return frozenset(converted_dtypes)
# -> 5067 include = check_int_infer_dtype(include)
#    5068 exclude = check_int_infer_dtype(exclude)
#    5070 for dtypes in (include, exclude):
#
# File c:\Users\SURAJ CHOUGULE\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5064, in DataFrame.select_dtypes.<locals>.check_int_infer_dtype(dtypes)
#    5062         converted_dtypes.extend([np.float64, np.float32])
#    5063     else:
# ...

# %%
df.select_dtypes(include=['bool','number'])
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone
# 0           0       3  22.0      1      0   7.2500        True  False
# 1           1       1  38.0      1      0  71.2833       False  False
# 2           1       3  26.0      0      0   7.9250       False   True
# 3           1       1  35.0      1      0  53.1000       False  False
# 4           0       3  35.0      0      0   8.0500        True   True
# ..        ...     ...   ...    ...    ...      ...         ...    ...
# 886         0       2  27.0      0      0  13.0000        True   True
# 887         1       1  19.0      0      0  30.0000       False   True
# 888         0       3   NaN      1      2  23.4500       False  False
# 889         1       1  26.0      0      0  30.0000        True   True
# 890         0       3  32.0      0      0   7.7500        True   True
#
# [891 rows x 8 columns]

# %%
# RENAME COLUMNS

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.DataFrame({"col A": [1,2,3,4],"col b": [5,6,7,8]})
df
# Out:
#    colo A  col b
# 0       1      5
# 1       2      6
# 2       3      7
# 3       4      8

# %%
pd.DataFrame(df)
# Out:
#    colo A  col b
# 0       1      5
# 1       2      6
# 2       3      7
# 3       4      8

# %%
pd.DataFrame(data_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pd.DataFrame(data_table)
#
# NameError: name 'data_table' is not defined

# %%
df.rename{ "col A" : "Column A"}
# Out:
#   Cell In[24], line 1
#     df.rename{ "col A" : "Column A"}
#              ^
# SyntaxError: invalid syntax

# %%
df.rename(columns={ "colo A": "Column A",'col b':"column B" })
# Out:
#    Column A  column B
# 0         1         5
# 1         2         6
# 2         3         7
# 3         4         8

# %%
df.columns=["column 1",'column 2']
df
# Out:
#    column 1  column 2
# 0         1         5
# 1         2         6
# 2         3         7
# 3         4         8

# %%
df.columns=df.columns.str.replace("",'_')
df
# Out:
#    ___c___o___l___u___m___n___ ___1___  ___c___o___l___u___m___n___ ___2___
# 0                                    1                                    5
# 1                                    2                                    6
# 2                                    3                                    7
# 3                                    4                                    8

# %% [markdown]
# #data filtering using python

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16108\1660334235.py in ?()
# ----> 1 df.unique()
#
# c:\Users\SURAJ CHOUGULE\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.alone.unique()
# Out:
# array([False,  True])

# %%
df.survived.unique()
# Out:
# array([0, 1])

# %%
df.alive.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df[df.sex=='female']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.sex=='female'].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df[df.sex=='female'].tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False

# %%
df[df.survived==1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.embark_town=='Southampton']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.embark_town=='Southampton'].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 6    man        True    E  Southampton    no   True

# %%
df[(df.sex=='female') & (df.survived==1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df.survived==1) | (df.sex=='female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df.survived==1) & (df.alone=='False')].shape
# Out:
# (0, 15)

# %%
df[(df.survived==1) & (df.alone=='False')].columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df[(df.survived==1) & (df.alone=='False')].index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# # now check for 3 conditions simultaneously like use now df[((1) & (2)) |(3)]

# %%
df[((df.age=='22') | (df.survived==1)) & (df.sex=='female')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df[((df.age=='22') | (df.survived==1)) & (df.sex=='female')]
#
# NameError: name 'df' is not defined

# %%
df[((df.age=='22') | (df.survived==1)) & (df.sex=='female')].shape
# Out:
# (233, 15)

# %%
df[((df.age=='22') | (df.survived==1)) & (df.sex=='female')].head
# Out:
# <bound method NDFrame.head of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
# ...

# %%
df[((df.age=='22') | (df.survived==1)) & (df.sex=='female')].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df[df.age.isin([20])]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 12          0       3    male  20.0      0      0   8.0500        S  Third
# 91          0       3    male  20.0      0      0   7.8542        S  Third
# 113         0       3  female  20.0      1      0   9.8250        S  Third
# 131         0       3    male  20.0      0      0   7.0500        S  Third
# 378         0       3    male  20.0      0      0   4.0125        C  Third
# 404         0       3  female  20.0      0      0   8.6625        S  Third
# 441         0       3    male  20.0      0      0   9.5000        S  Third
# 622         1       3    male  20.0      1      1  15.7417        C  Third
# 640         0       3    male  20.0      0      0   7.8542        S  Third
# 664         1       3    male  20.0      1      0   7.9250        S  Third
# 682         0       3    male  20.0      0      0   9.2250        S  Third
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[df.embark_town.isin([Southampton])].shape
#
# NameError: name 'Southampton' is not defined

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.age.isin([30])].shape # type: ignore
# Out:
# (25, 15)

# %% [markdown]
# # Aggreagate by cols and select specific rows and col
# # 4july

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.groupby('sex').count()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
df.groupby('alone').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# alone
# False       354     354  354  310    354    354   354       354    354  354
# True        537     537  537  404    537    537   537       535    537  537
#
#        adult_male  deck  embark_town  alive
# alone
# False         354   110          354    354
# True          537    93          535    537

# %%
df.groupby('pclass').count()
# Out:
#         survived  sex  age  sibsp  parch  fare  embarked  class  who  \
# pclass
# 1            216  216  186    216    216   216       214    216  216
# 2            184  184  173    184    184   184       184    184  184
# 3            491  491  355    491    491   491       491    491  491
#
#         adult_male  deck  embark_town  alive  alone
# pclass
# 1              216   175          214    216    216
# 2              184    16          184    184    184
# 3              491    12          491    491    491

# %%
df.groupby('survived').count()
# Out:
#           pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# survived
# 0            549  549  424    549    549   549       549    549  549
# 1            342  342  290    342    342   342       340    342  342
#
#           adult_male  deck  embark_town  alive  alone
# survived
# 0                549    67          549    549    549
# 1                342   136          340    342    342

# %%
len(df)
# Out:
# 891

# %%
len(df.sex)
# Out:
# 891

# %%
len(df.groupby('sex'))
# Out:
# 2

# %%
df.groupby(['alone','pclass','class','sex']).count()
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_20748\7622344.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['alone','pclass','class','sex']).count()
#                             survived  age  sibsp  parch  fare  embarked  who  \
# alone pclass class  sex
# False 1      First  female        60   53     60     60    60        60   60
#                     male          47   47     47     47    47        47   47
#              Second female         0    0      0      0     0         0    0
#                     male           0    0      0      0     0         0    0
#              Third  female         0    0      0      0     0         0    0
#                     male           0    0      0      0     0         0    0
# ...

# %%
len(df.groupby('class'))
# Out:
# C:\Users\SURAJ CHOUGULE\AppData\Local\Temp\ipykernel_20748\733745045.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   len(df.groupby('class'))
# 3

# %%
len(df.groupby('pclass'))
# Out:
# 3

# %%
len(df.groupby('alone'))
# Out:
# 2

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[['survived','pclass']]
# Out:
#      survived  pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]
